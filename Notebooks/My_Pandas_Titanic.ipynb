# %%
import numpy as np
import pandas as pd

df = pd.read_csv('Datasets/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import matplotlib.pyplot as plt

df['Age'].hist(bins=16)
plt.show()

# %%
df['Age'].isna().sum()
# Out:
# 177

# %% [markdown]
# #### So for 177 pasengers there is no report of age

# %%
df['Gender'] = df['Sex'].map({'female':0, 'male': 1}).astype(int)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
df.shape
# Out:
# (891, 13)

# %%
df['Age'].plot.box()

# %%
df['Age'].dropna().values
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  , 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 31.  , 35.  ,
#        34.  , 15.  , 28.  ,  8.  , 38.  , 19.  , 40.  , 66.  , 28.  ,
#        42.  , 21.  , 18.  , 14.  , 40.  , 27.  ,  3.  , 19.  , 18.  ,
#         7.  , 21.  , 49.  , 29.  , 65.  , 21.  , 28.5 ,  5.  , 11.  ,
#        22.  , 38.  , 45.  ,  4.  , 29.  , 19.  , 17.  , 26.  , 32.  ,
#        16.  , 21.  , 26.  , 32.  , 25.  ,  0.83, 30.  , 22.  , 29.  ,
#        28.  , 17.  , 33.  , 16.  , 23.  , 24.  , 29.  , 20.  , 46.  ,
#        26.  , 59.  , 71.  , 23.  , 34.  , 34.  , 28.  , 21.  , 33.  ,
#        37.  , 28.  , 21.  , 38.  , 47.  , 14.5 , 22.  , 20.  , 17.  ,
#        21.  , 70.5 , 29.  , 24.  ,  2.  , 21.  , 32.5 , 32.5 , 54.  ,
#        12.  , 24.  , 45.  , 33.  , 20.  , 47.  , 29.  , 25.  , 23.  ,
#        19.  , 37.  , 16.  , 24.  , 22.  , 24.  , 19.  , 18.  , 19.  ,
# ...

# %%
df[df['Embarked']=='C'].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 9            10         1       2
# 19           20         1       3
# 26           27         0       3
# 30           31         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Gender
# 1       0  PC 17599  71.2833   C85        C       0
# 9       0    237736  30.0708   NaN        C       0
# 19      0      2649   7.2250   NaN        C       0
# 26      0      2631   7.2250   NaN        C       1
# ...

# %%
# how many people embarked in section C
len(df[df['Embarked']=='C'])
# Out:
# 168

# %%
pd.set_option('display.max_rows', None)
df[df['Embarked']=='C']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# 31            32         1       1
# 34            35         0       1
# 36            37         1       3
# 39            40         1       3
# 42            43         0       3
# 43            44         1       2
# 48            49         0       3
# 52            53         1       1
# 54            55         0       1
# 57            58         0       3
# 60            61         0       3
# 64            65         0       1
# 65            66         1       3
# 73            74         0       3
# 96            97         0       1
# 97            98         1       1
# 111          112         0       3
# 114          115         0       3
# 118          119         0       1
# 122          123         0       2
# ...

# %% [markdown]
# ## Plot the age range for those who Embarked were 'C'

# %%
age = df[df['Embarked']=='C']
age['Age'].hist(bins=16)
plt.show()

# %%
df[df.Embarked == 'C'].Age.hist(bins=10)
plt.show()

# %%
df[df['Embarked']=='C']['Age'].plot(kind='kde')

# %%
df['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
ls_embark = df['Embarked'].dropna().values

# %%
len(ls_embark)
# Out:
# 889

# %%
ls_embark[:10]
# Out:
# array(['S', 'C', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'C'], dtype=object)

# %% [markdown]
# ## How many unique values does ls_embark have? What is the frequency of these unique values?

# %%
df['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %% [markdown]
# ### Create histogram dictionary by passing ls_embark list into it

# %%
# PYTHON WAY

hist = {}
for item in df['Embarked']:
    hist[item] = hist.get(item, 0) + 1

# %%
print(hist)
# Out:
# {'S': 644, 'C': 168, 'Q': 77, nan: 2}

# %%
df['Embarked'].nunique()
# Out:
# 3

# %% [markdown]
# ### 3 unique values

# %%
# PANDAS WAY

df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
dict(df['Embarked'].value_counts())
# Out:
# {'S': 644, 'C': 168, 'Q': 77}

# %%
dict(df['Embarked'].value_counts())['S']
# Out:
# 644

# %%
df['Embarked'].value_counts().plot(kind='bar')

# %%
df['Embarked'].value_counts().plot(kind ='barh').invert_yaxis()

# %% [markdown]
# ### Another way to do the count and plot it

# %%
import seaborn as sns

sns.countplot(x='Embarked', palette='spring', data=df)

# %% [markdown]
# ### How many female and male passengers on the Titanic?

# %%
dict(df['Sex'].value_counts())
# Out:
# {'male': 577, 'female': 314}

# %%
# pass from backend to frontend w json

df['Sex'].value_counts().to_json()
# Out:
# '{"male":577,"female":314}'

# %%
df['Sex'].value_counts().plot(kind='bar')

# %%
df['Sex'].value_counts().plot(kind='pie')

# %%
for i in df[df['Embarked'] == 'C'].groupby('Sex')['Age']:
    print(i)
# Out:
# ('female', 1      38.00
# 9      14.00
# 19       NaN
# 31       NaN
# 39     14.00
# 43      3.00
# 52     49.00
# 111    14.50
# 114    17.00
# 128      NaN
# 140      NaN
# 177    50.00
# 194    44.00
# 195    58.00
# 215    31.00
# 218    32.00
# 240      NaN
# 255    29.00
# 256      NaN
# 258    35.00
# 291    19.00
# 299    50.00
# 306      NaN
# 307    17.00
# 309    30.00
# 310    24.00
# 311    18.00
# 319    40.00
# 325    36.00
# 329    16.00
# 337    41.00
# 362    45.00
# 366    60.00
# 367      NaN
# 369    24.00
# 375      NaN
# 380    42.00
# 381     1.00
# 389    17.00
# 393    23.00
# 448     5.00
# 469     0.75
# 473    23.00
# 496    54.00
# 513    54.00
# 523    44.00
# 533      NaN
# 537    30.00
# 539    22.00
# 556    48.00
# 578      NaN
# 581    39.00
# 591    52.00
# 608    22.00
# 641    24.00
# 644     0.75
# 691     4.00
# 700    18.00
# 702    18.00
# 710    24.00
# 716    38.00
# 742    21.00
# 780    13.00
# 830    15.00
# 835    39.00
# ...

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].hist(bins=16, alpha=0.5)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
df[df['Embarked']=='C'].groupby('Sex')['Age'].plot(bins=16, kind='hist', legend=True, alpha=0.5)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].value_counts()
# Out:
# Sex     Age
# female  24.00    5
#         17.00    3
#         18.00    3
#         30.00    3
#         0.75     2
#         14.00    2
#         15.00    2
#         22.00    2
#         23.00    2
#         38.00    2
#         39.00    2
#         44.00    2
#         50.00    2
#         54.00    2
#         1.00     1
#         3.00     1
#         4.00     1
#         5.00     1
#         9.00     1
#         13.00    1
#         14.50    1
#         16.00    1
#         19.00    1
#         21.00    1
#         27.00    1
#         28.00    1
#         29.00    1
#         31.00    1
#         32.00    1
#         35.00    1
#         36.00    1
#         40.00    1
#         41.00    1
#         42.00    1
#         45.00    1
#         48.00    1
#         49.00    1
#         52.00    1
#         56.00    1
#         58.00    1
#         60.00    1
# male    25.00    4
#         30.00    4
#         20.00    3
#         22.00    3
#         26.00    3
# ...

# %% [markdown]
# ## What is the average Age for female and male (based on sex) for those who have 'Embarked' on section 'C'?

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    28.344262
# male      32.998841
# Name: Age, dtype: float64

# %% [markdown]
# ### Whigh age is the oldest

# %%
df[df['Embarked']=='C'].groupby('Sex')['Age'].agg(np.max)
# Out:
# Sex
# female    60.0
# male      71.0
# Name: Age, dtype: float64

# %%
# REGRESSION PLOT
sns.regplot(x='Age', y='Fare', fit_reg=False, data=df)

# %%
df.plot.scatter(x='Age', y='Fare')

# %%
sns.barplot(x="Sex", y="Survived", hue="Pclass", data=df)

# %%
import seaborn as sns

sns.regplot(x='Age', y='Fare', fit_reg=False, data=df)

# %%
sns.barplot(x="Age", y="Fare", hue="Sex", data=df)

# %% [markdown]
# ## Plot how many male or female were in different Passenger classes for those who embarked on section 'C'

# %%
sns.countplot(x="Sex", hue="Pclass", data=df[df['Embarked']=='C'])

# %% [markdown]
# ## Plot how many male or female were in different passenger classes for those who embarked at section C and survived

# %%
sns.countplot(x='Sex', hue="Pclass", data=df[(df.Embarked=='C') & (df.Survived== 1)])

# %%
sns.countplot(x="Sex", hue="Pclass", data=df[(df['Embarked']=='C') & (df['Survived'] == 1)])

# %% [markdown]
# Question: What femail percentage on Pclass1 survived?
#
# Hint: Do data-frame slicing for females and Class 1 first

# %%
df[(df['Sex'] == 'female') & (df['Pclass']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# 61            62         1       1
# 88            89         1       1
# 136          137         1       1
# 151          152         1       1
# 166          167         1       1
# 177          178         0       1
# 194          195         1       1
# 195          196         1       1
# 215          216         1       1
# 218          219         1       1
# 230          231         1       1
# 256          257         1       1
# 257          258         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 275          276         1       1
# 290          291         1       1
# 291          292         1       1
# 297          298         0       1
# ...

# %%
df[(df['Sex'] == 'female') & (df['Pclass']==1)]['Survived'].value_counts()
# Out:
# 1    91
# 0     3
# Name: Survived, dtype: int64

# %%
91/(91+3)
# Out:
# 0.9680851063829787

# %% [markdown]
# ### The above got us the top of the blue below

# %%
sns.barplot(x="Sex", y="Survived", hue="Pclass", data=df)

# %% [markdown]
# ### Stack plot of count based on Sex for different Passenger Class

# %%
df.groupby(['Sex'])['Pclass'].value_counts().unstack().plot(kind='bar', stacked=True)

# %%
df.groupby(['Sex', 'Survived'])['Pclass'].value_counts().unstack().plot(kind='bar', stacked=True)

# %% [markdown]
# ### How many females were in Pclass 2 and how many male were in Pclass 2 ?

# %%
df[(df['Sex'] == 'female') & (df['Pclass']==2)]['Survived'].value_counts()
# Out:
# 1    70
# 0     6
# Name: Survived, dtype: int64

# %%
df[(df['Sex'] == 'male') & (df['Pclass']==2)]['Survived'].value_counts()
# Out:
# 0    91
# 1    17
# Name: Survived, dtype: int64

# %% [markdown]
# ## Quiz: How many female were in Pclass 2 and how many male?

# %%
df[df['Pclass']==2]['Sex'].value_counts()
# Out:
# male      108
# female     76
# Name: Sex, dtype: int64

# %%
dict(df.groupby('Sex')['Pclass'].value_counts())
# Out:
# {('female', 3): 144,
#  ('female', 1): 94,
#  ('female', 2): 76,
#  ('male', 3): 347,
#  ('male', 1): 122,
#  ('male', 2): 108}

# %%
pd.crosstab(df['Sex'], df['Pclass'])
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
df[df['Pclass']==2]['Sex'].value_counts()
# Out:
# male      108
# female     76
# Name: Sex, dtype: int64

# %%
pd.crosstab(df['Sex'], df['Pclass'])
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %% [markdown]
# ## How to represent the above cross tab in percentage and graphically present

# %%
sns.heatmap(pd.crosstab(df['Sex'], df['Embarked'], normalize='index'), cmap="YlGnBu", annot=True)

# %% [markdown]
# Q: What percentage of passengers embarked at C ?

# %%
df[df['Embarked'] == 'C']['Embarked'].value_counts()
# Out:
# C    168
# Name: Embarked, dtype: int64

# %%
pd.crosstab(df['Sex'], df['Embarked'])
# Out:
# Embarked   C   Q    S
# Sex
# female    73  36  203
# male      95  41  441

# %%
73 + 95
# Out:
# 168

# %%
73+95+36+41+203+441
# Out:
# 889

# %%
168/889 * 100
# Out:
# 18.89763779527559

# %%
print(dict(df['Embarked'].value_counts()))
# Out:
# {'S': 644, 'C': 168, 'Q': 77}

# %%
sum(dict(df['Embarked'].value_counts()).values())
# Out:
# 889

# %%
len(df[df["Embarked"]== "C"])
# Out:
# 168

# %% [markdown]
# What percentage of female passengers embarked on C ?

# %%
pd.crosstab(df['Sex'], df['Embarked']=='C')
# Out:
# Embarked  False  True
# Sex
# female      241     73
# male        482     95

# %%
pd.crosstab(df['Sex'], df['Embarked'])
# Out:
# Embarked   C   Q    S
# Sex
# female    73  36  203
# male      95  41  441

# %% [markdown]
# what is the average age of male passengers that survived?

# %%
male = male.dropna()
df[df['Sex']=='male']['Age'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-5cc2f2d1120b> in <module>
# ----> 1 male = male.dropna()
#       2 df[df['Sex']=='male']['Age'].mean()
#
# NameError: name 'male' is not defined

# %%
df[(df['Sex'] == 'male') & (df['Survived']==1)].mean()
# Out:
# PassengerId    475.724771
# Survived         1.000000
# Pclass           2.018349
# Age             27.276022
# SibSp            0.385321
# Parch            0.357798
# Fare            40.821484
# Gender           1.000000
# dtype: float64

# %%
df[(df['Sex'] =='male') & (df['Survived'] == 1)]['Age'].mean()
# Out:
# 27.276021505376345

# %%
def compute_mode(dataset):
    """ Main function that determines the mode value across our data. """
    mode = -np.inf
    hist = {}
    for item in data:
        hist[item] = hist.get(item, 0) + 1
        mode = hist[item] if hist[item] > mode else mode
        return mode
    mode = item if hist[item] > mode else mode

# %%
df = pd.DataFrame({'Rainy':[29,28,32,35,36,12,18,30,45,55, 32,32,32,32,32], 'City':['City_A']*5 + ['City_B']*5 + ['City_C']*5})

# %%
df
# Out:
#     Rainy    City
# 0      29  City_A
# 1      28  City_A
# 2      32  City_A
# 3      35  City_A
# 4      36  City_A
# 5      12  City_B
# 6      18  City_B
# 7      30  City_B
# 8      45  City_B
# 9      55  City_B
# 10     32  City_C
# 11     32  City_C
# 12     32  City_C
# 13     32  City_C
# 14     32  City_C

# %%
fare= df.Fare.values
np.percentile(fare, 75)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-5013461a0a1f> in <module>
# ----> 1 fare= df.Fare.values
#       2 np.percentile(fare, 75)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Fare'
