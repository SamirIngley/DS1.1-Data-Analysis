# %%
import numpy as np
import pandas as pd

df = pd.read_csv('Datasets/titanic.csv')
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.shape # rows, columns
# Out:
# (891, 12)

# %%
df[['Survived', 'Pclass']]
# Out:
#      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 886         0       2
# 887         1       1
# 888         0       3
# 889         1       1
# 890         0       3
#
# [891 rows x 2 columns]

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['Pclass'].nunique()
# Out:
# 3

# %%
df[df['Pclass'] == 3]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[df['Pclass'] == 3].shape
# Out:
# (491, 12)

# %%
len(df[df['Pclass']==3])
# Out:
# 491

# %%
len(df[(df['Pclass']==3) & (df['Survived'])])
# Out:
# 119

# %%
df[(df['Pclass']==3) & (df['Survived'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 19            20         1       3
# 22            23         1       3
# ..           ...       ...     ...
# 838          839         1       3
# 855          856         1       3
# 858          859         1       3
# 869          870         1       3
# 875          876         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dict(df['Survived'].value_counts())
# Out:
# {0: 549, 1: 342}

# %% [markdown]
# ## How many passengers survived in Pclass 3?

# %%
df[df['Pclass']==3]['Survived'] # survived column for passengers at class 3
# Out:
# 0      0
# 2      1
# 4      0
# 5      0
# 7      0
#       ..
# 882    0
# 884    0
# 885    0
# 888    0
# 890    0
# Name: Survived, Length: 491, dtype: int64

# %%
# then we should count how many 1's we have
dict(df[df['Pclass']==3]['Survived'].value_counts())
# Out:
# {0: 372, 1: 119}

# %%
# How many passengers are in Pclass 2 and 3
dict(df['Pclass'].value_counts())
# Out:
# {3: 491, 1: 216, 2: 184}

# %%
pd.crosstab(df['Survived'], df['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
# How many passengers we have in Pclass 3 or Pclass 2

# %%
len(df[(df['Pclass']==2) | (df['Pclass']==3)])
# Out:
# 675

# %%
len(df[df['Pclass']==2] + df[df['Pclass']==3])
# Out:
# 675

# %%
df[(df['Pclass']==2) | (df['Pclass'] ==3)]['Survived'].value_counts()
# Out:
# 0    469
# 1    206
# Name: Survived, dtype: int64

# %%
dict(df[df['Pclass']==2]['Survived'].value_counts())
# Out:
# {0: 97, 1: 87}

# %%
dict(df[df['Pclass']==3]['Sex'])
# Out:
# {0: 'male',
#  2: 'female',
#  4: 'male',
#  5: 'male',
#  7: 'male',
#  8: 'female',
#  10: 'female',
#  12: 'male',
#  13: 'male',
#  14: 'female',
#  16: 'male',
#  18: 'female',
#  19: 'female',
#  22: 'female',
#  24: 'female',
#  25: 'female',
#  26: 'male',
#  28: 'female',
#  29: 'male',
#  32: 'female',
#  36: 'male',
#  37: 'male',
#  38: 'female',
#  39: 'female',
#  40: 'female',
#  42: 'male',
#  44: 'female',
#  45: 'male',
#  46: 'male',
#  47: 'female',
#  48: 'male',
#  49: 'female',
#  50: 'male',
#  51: 'male',
#  57: 'male',
#  59: 'male',
#  60: 'male',
#  63: 'male',
#  65: 'male',
#  67: 'male',
#  68: 'female',
#  69: 'male',
#  71: 'female',
#  73: 'male',
#  74: 'male',
#  75: 'male',
#  76: 'male',
#  77: 'male',
#  79: 'female',
#  80: 'male',
#  81: 'male',
#  82: 'female',
#  85: 'female',
#  86: 'male',
#  87: 'male',
#  89: 'male',
#  90: 'male',
#  91: 'male',
#  93: 'male',
#  94: 'male',
#  95: 'male',
#  100: 'female',
#  101: 'male',
# ...

# %%
df['Survived'].value_counts().plot(kind='bar')
